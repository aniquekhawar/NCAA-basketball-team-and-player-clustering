# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sportsreference.ncaab.roster import Roster
from sportsreference.ncaab.roster import Player
from sportsipy.ncaab.teams import Team, Teams

pd.set_option('display.max_columns', None)

# %% [markdown]
# # Select teams and years you want
# > I chose to include the years 2010 to 2020 (inclusive) and to only get players from Duke and Kentucky. In the function below, we'll pull all the player ids into a set (if there are duplicate items, it simply doesn't add them).

# %%
# years from 2010 to 2020
years = np.arange(2010, 2021, 1).astype(str)
teams = ['Duke', 'Kentucky']
player_ids = set()
# iterate through teams
for team in teams:
    # iterate through years for an individual team
    for year in years:
        data = Roster(team, year = year)
        for player in data.players:
            # add the player id to a set
            # if they already exist, the set won't add them
            player_ids.add(player.player_id)

# %% [markdown]
# ## Initialize an empty dataframe
# > We'll use this to concatenate data to.
#
# ### use a get_player_df function to grab some player information (useful stuff would be names and season years, including career which looks like an aggregate)
# [Sportsreference Medium Article I used](https://towardsdatascience.com/sports-reference-api-intro-dbce09e89e52?gi=ce7f0fc79a3e)

# %%
df = pd.DataFrame()

# %%
# Function to get player info from Player class object.
def get_player_df(player):
    
    # helper function to get player age during each season.
    def get_age(year, bd):
        if year[0] == "Career":
            return None
        else:
            year_dt = datetime(int(year[0][0:4]) + 1, 1, 1)
            age_years = relativedelta(year_dt, bd).years + relativedelta(year_dt, bd).months/12
            return age_years
        
    # helper function to get year for each row and denote
    # rows that contain career totals.
    def get_year(ix):
        if ix[0] == "Career":
            return "Career"
        elif ix[0] == "1999-00":
            return "2000"
        else:
            return ix[0][0:2] + ix[0][-2:]
    
    # get player df and add some extra info
    player_df = player.dataframe
    player_df['player_id'] = player.player_id
    player_df['name'] = player.name
    player_df['year'] = [get_year(ix) for ix in player_df.index]
    player_df['id'] = [player_id + ' ' + year for player_id,
                       year in zip(player_df['player_id'],
                       player_df['year'])]
    player_df.set_index('id', drop = True, inplace = True)
    
    return player_df

# %% [markdown]
# ## Loop through player ids and get all the players into a single dataframe

# %%
for player_id in player_ids:
    player = Player(player_id)
    player_frame = get_player_df(player)
    df = pd.concat([df, player_frame])
df
# Out:
#                            assist_percentage  assists block_percentage  \
# id
# dominique-hawkins-1 2014                 7.2       12              0.4
# dominique-hawkins-1 2015                14.9       14              0.7
# dominique-hawkins-1 2016                 8.2       13              1.2
# dominique-hawkins-1 2017                13.1       64              0.0
# dominique-hawkins-1 Career              11.3      103              0.4
# ...                                      ...      ...              ...
# justise-winslow-1 Career                13.2       82              2.9
# nick-richards-2 2018                     3.0        9              7.0
# nick-richards-2 2019                     2.9        7             12.0
# nick-richards-2 2020                     1.7        7              8.0
# nick-richards-2 Career                   2.3       23              8.7
#
#                             blocks box_plus_minus conference  \
# id
# dominique-hawkins-1 2014         1           -0.4        sec
# dominique-hawkins-1 2015         1            3.5        sec
# dominique-hawkins-1 2016         3            4.1        sec
# dominique-hawkins-1 2017         0            5.9        sec
# dominique-hawkins-1 Career       5            4.1
# ...                            ...            ...        ...
# justise-winslow-1 Career        34           10.0
# nick-richards-2 2018            33            5.7        sec
# nick-richards-2 2019            47            6.6        sec
# nick-richards-2 2020            66            7.0        sec
# nick-richards-2 Career         146            6.5
#
#                            defensive_box_plus_minus  \
# id
# dominique-hawkins-1 2014                        3.0
# dominique-hawkins-1 2015                        5.6
# dominique-hawkins-1 2016                        2.4
# dominique-hawkins-1 2017                        4.7
# dominique-hawkins-1 Career                      4.0
# ...                                             ...
# justise-winslow-1 Career                        4.6
# nick-richards-2 2018                            3.1
# nick-richards-2 2019                            4.8
# nick-richards-2 2020                            2.4
# nick-richards-2 Career                          3.1
#
#                            defensive_rebound_percentage  defensive_rebounds  \
# id
# dominique-hawkins-1 2014                            6.2                  16
# dominique-hawkins-1 2015                            8.6                  13
# dominique-hawkins-1 2016                            3.9                   9
# dominique-hawkins-1 2017                            5.7                  39
# dominique-hawkins-1 Career                          5.8                  77
# ...                                                 ...                 ...
# justise-winslow-1 Career                           19.8                 203
# nick-richards-2 2018                               20.7                 108
# nick-richards-2 2019                               16.5                  66
# nick-richards-2 2020                               18.6                 160
# nick-richards-2 Career                             18.7                 334
#
#                            defensive_win_shares  ... turnovers  \
# id                                               ...
# dominique-hawkins-1 2014                    0.3  ...         6
# dominique-hawkins-1 2015                    0.4  ...         5
# dominique-hawkins-1 2016                    0.3  ...         6
# dominique-hawkins-1 2017                    1.2  ...        18
# dominique-hawkins-1 Career                  2.1  ...        35
# ...                                         ...  ...       ...
# justise-winslow-1 Career                    2.5  ...        71
# nick-richards-2 2018                        1.0  ...        26
# nick-richards-2 2019                        1.0  ...        26
# nick-richards-2 2020                        1.6  ...        49
# nick-richards-2 Career                      3.6  ...       101
#
#                             two_point_attempts two_point_percentage  \
# id
# dominique-hawkins-1 2014                    15                0.467
# dominique-hawkins-1 2015                    14                0.357
# dominique-hawkins-1 2016                    17                0.529
# dominique-hawkins-1 2017                    75                0.453
# dominique-hawkins-1 Career                 121                0.455
# ...                                        ...                  ...
# justise-winslow-1 Career                   246                0.516
# nick-richards-2 2018                       112                0.616
# nick-richards-2 2019                        82                0.598
# nick-richards-2 2020                       254                0.642
# nick-richards-2 Career                     448                0.627
#
#                             two_pointers usage_percentage  weight win_shares  \
# id
# dominique-hawkins-1 2014               7              7.6     195        0.3
# dominique-hawkins-1 2015               5             14.4     195        0.5
# dominique-hawkins-1 2016               9             12.8     195        0.7
# dominique-hawkins-1 2017              34             11.5     195        2.5
# dominique-hawkins-1 Career            55             11.3     195        4.0
# ...                                  ...              ...     ...        ...
# justise-winslow-1 Career             127             22.9     225        5.5
# nick-richards-2 2018                  69             15.5     247        2.4
# nick-richards-2 2019                  49             16.2     247        2.2
# nick-richards-2 2020                 163             20.7     247        5.1
# nick-richards-2 Career               281             18.2     247        9.6
#
#                             win_shares_per_40_minutes               name  \
# id
# dominique-hawkins-1 2014                        0.035  Dominique Hawkins
# dominique-hawkins-1 2015                        0.113  Dominique Hawkins
# dominique-hawkins-1 2016                         0.12  Dominique Hawkins
# dominique-hawkins-1 2017                        0.137  Dominique Hawkins
# dominique-hawkins-1 Career                      0.111  Dominique Hawkins
# ...                                               ...                ...
# justise-winslow-1 Career                        0.196    Justise Winslow
# nick-richards-2 2018                            0.173      Nick Richards
# nick-richards-2 2019                            0.193      Nick Richards
# nick-richards-2 2020                            0.222      Nick Richards
# nick-richards-2 Career                          0.201      Nick Richards
#
#                               year
# id
# dominique-hawkins-1 2014      2014
# dominique-hawkins-1 2015      2015
# dominique-hawkins-1 2016      2016
# dominique-hawkins-1 2017      2017
# dominique-hawkins-1 Career  Career
# ...                            ...
# justise-winslow-1 Career    Career
# nick-richards-2 2018          2018
# nick-richards-2 2019          2019
# nick-richards-2 2020          2020
# nick-richards-2 Career      Career
#
# [534 rows x 53 columns]

# %% [markdown]
# ## Export all your work for later use.

# %%
df.to_csv('data/duke_kentucky_2010_to_2020.csv', index_label = 'id')
